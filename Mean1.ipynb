# %% [markdown]
# <a href="https://colab.research.google.com/github/Shreeeeeeeeeeeee/CTRW_2state/blob/main/Mean1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
MSD1_1 = np.load("/content/msd1_1.npy")

# %%
print(MSD1_1),len(MSD1_1)
# Out:
# [[-1.75724328e-06  1.57862487e-06  1.09840691e-05 ... -6.93407657e-06
#    1.51968004e-06 -3.31049263e-06]
#  [ 2.48194045e-01  2.25516222e-01  3.62815992e-01 ...  4.46878775e-01
#    4.43266853e-01  2.04000953e-01]
#  [ 4.70723656e-01  4.31954280e-01  6.98800901e-01 ...  7.52850560e-01
#    8.74152651e-01  3.85095959e-01]
#  ...
#  [ 1.57544362e+01  1.63462640e+01  6.54811422e+01 ...  3.06941173e+02
#    9.16741925e+01  8.42850684e+01]
#  [ 1.54313143e+01  1.75070043e+01  7.02072404e+01 ...  3.11822778e+02
#    9.20380491e+01  8.63399367e+01]
#  [ 1.16095046e+01  2.09940174e+01  8.92559350e+01 ...  3.25289992e+02
#    9.40231369e+01  9.23473416e+01]]
# (None, 10000)

# %%
TIM1_1 = np.load("/content/tim1_1.npy")

# %%
MSD1_2 = np.load("/content/msd1_2.npy")

# %%
MSD1_3 = np.load("/content/msd1_3.npy")

# %%
MSD1_4 = np.load("/content/msd1_4.npy")

# %%
MSD1_5 = np.load("/content/msd1_5.npy")

# %%
MSD1_6 = np.load("/content/msd1_6.npy")

# %%
MSD1_7 = np.load("/content/msd1_7.npy")

# %%
MSD1_8 = np.load("/content/msd1_8.npy")

# %%
MSD1_9 = np.load("/content/msd1_9.npy")

# %%
#plt.plot(tim,alpha_avg, label="Exponential")
plt.plot(tim1,alpha_avg1, label="Uniform")
plt.ylim(-0.05,1.05)
plt.axhline(1.0, ls=":", color="black")
plt.xscale("log")
plt.legend()
plt.xlabel("Time (ps)")
plt.ylabel("Alpha")

# %%
msd1_avg = np.average(MSD1_1,axis=1)
msd2_avg = np.average(MSD1_2,axis=1)
msd3_avg = np.average(MSD1_3,axis=1)
msd4_avg = np.average(MSD1_4,axis=1)
msd5_avg = np.average(MSD1_5,axis=1)
msd6_avg = np.average(MSD1_6,axis=1)
msd7_avg = np.average(MSD1_7,axis=1)
msd8_avg = np.average(MSD1_8,axis=1)
msd9_avg = np.average(MSD1_9,axis=1)

# %%
plt.plot(TIM1_1,msd1_avg,label='0.1')
plt.plot(TIM1_1,msd2_avg,label='0.15')
plt.plot(TIM1_1,msd3_avg,label='0.2')
plt.plot(TIM1_1,msd4_avg,label='0.25')
plt.plot(TIM1_1,msd5_avg,label='0.3')
plt.plot(TIM1_1,msd6_avg,label='0.35')
plt.plot(TIM1_1,msd7_avg,label='0.4')
plt.plot(TIM1_1,msd8_avg,label='0.45')
plt.plot(TIM1_1,msd9_avg,label='0.5')
plt.xlabel("Time (ps)")
plt.ylabel("MSD")
plt.xscale("log")
plt.yscale("log")
plt.ylim(0.1,200)
plt.legend()

# %%
ALPHA1_1 = np.load("/content/alpha1_1.npy")

# %%
ALPHA1_2 = np.load("/content/alpha1_2.npy")

# %%
ALPHA1_3 = np.load("/content/alpha1_3.npy")

# %%
ALPHA1_4 = np.load("/content/alpha1_4.npy")

# %%
ALPHA1_5 = np.load("/content/alpha1_5.npy")

# %%
ALPHA1_6 = np.load("/content/alpha1_6.npy")

# %%
ALPHA1_7 = np.load("/content/alpha1_7.npy")

# %%
ALPHA1_8 = np.load("/content/alpha1_8.npy")

# %%
ALPHA1_9 = np.load("/content/alpha1_9.npy")

# %%
plt.plot(TIM1_1,ALPHA1_1,label="0.1")
plt.plot(TIM1_1,ALPHA1_2,label='0.15')
plt.plot(TIM1_1,ALPHA1_3,label='0.2')
plt.plot(TIM1_1,ALPHA1_4,label='0.25')
plt.plot(TIM1_1,ALPHA1_5,label='0.3')
plt.plot(TIM1_1,ALPHA1_6,label='0.35')
plt.plot(TIM1_1,ALPHA1_7,label='0.4')
plt.plot(TIM1_1,ALPHA1_8,label='0.45')
plt.plot(TIM1_1,ALPHA1_9,label='0.5')
plt.ylim(-0.05,1.05)
plt.axhline(1.0, ls=":", color="black")
plt.xscale("log")
plt.legend()
plt.xlabel("Time (ps)")
plt.ylabel("Alpha")
# Out:
# Text(0, 0.5, 'Alpha')
